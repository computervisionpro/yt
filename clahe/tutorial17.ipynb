# %% [markdown]
# # Histogram Equalization

# %% [markdown]
# ![clhe2.png](attachment:clhe2.png)

# %% [markdown]
# ![clhe3.png](attachment:clhe3.png)

# %%
# Source: https://docs.opencv.org/master/d5/daf/tutorial_py_histogram_equalization.html

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # CLAHE

# %% [markdown]
# ![sun-light.jpg](attachment:sun-light.jpg)

# %%
# Image: https://unsplash.com/photos/AjmBvSj_2IE

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('sun-light.jpg')
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

h, s, v = hsv_img[:,:,0], hsv_img[:,:,1], hsv_img[:,:,2]

# %%
clahe = cv2.createCLAHE(clipLimit = 15.0, tileGridSize = (20,20))
v = clahe.apply(v)

hsv_img = np.dstack((h,s,v))

rgb = cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB)
plt.imshow(rgb);
