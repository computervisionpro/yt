# %% [markdown]
# # Contour matching

# %% [markdown]
# ![Inkedshape-match.jpg](attachment:Inkedshape-match.jpg)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
import cv2
import matplotlib.pyplot as plt

# %%
def bin_img(image):
    img = cv2.imread(image)
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    binary_img = cv2.threshold(gray_img, 50, 255, cv2.THRESH_BINARY_INV)[1]
    plt.imshow(binary_img, cmap='gray')
    
    return binary_img

# %%
binary_img1 = bin_img('tiger1.jpg')

# %%
binary_img2 = bin_img('tiger2.jpg')

# %%
contour1, heirarchy = cv2.findContours(binary_img1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contour2, heirarchy = cv2.findContours(binary_img2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
cont_diff = cv2.matchShapes(contour1[0], contour2[0], cv2.CONTOURS_MATCH_I1, 0)
#Hu Moments
cont_diff
# Out:
# 0.0077114914335052465

# %%
binary_img3 = bin_img('gorilla.png')
contour3, heirarchy = cv2.findContours(binary_img3, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
cont_diff = cv2.matchShapes(contour1[0], contour3[0], cv2.CONTOURS_MATCH_I1, 0)
cont_diff
# Out:
# 0.553126707534437
