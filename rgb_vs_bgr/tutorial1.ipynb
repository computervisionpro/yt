# %%
import numpy as np
import cv2

# %%
img_dir = 'C:\\Computer-Vision-Practice\\'
image = img_dir+'messi.jpg'

im= cv2.imread(image)

# %%
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()

# %%
im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)
